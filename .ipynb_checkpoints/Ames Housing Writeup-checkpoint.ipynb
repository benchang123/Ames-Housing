# %% [markdown]
# # Ames Housing Prices
#
# ## Purpose of the Analysis:
#
# ### Find out which Variables Strongly Affect the Housing Prices
#
# The goal of this project is to determine which variables most strongly correlate to the housing prices in Ames, Iowa. The parts of the notebook is split into the EDA, Feature Engineering, and Modeling where regression will be conducted. Three types of regression will be conducted (Ordinary Least Square, Ridge Regression, and Lasso Regression). The root means squared error will be used to determine the training error, cross validation error, and test error.
#
# The file codebook.txt in the repository gives a description of what each independent variable is in the data.
#
# Some of the ideas presented in this project comes from the Data 200 course at UC Berkeley. The link to the course is here: http://www.ds100.org/su20/

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn import linear_model as lm
from sklearn import preprocessing
from sklearn import metrics
from sklearn import ensemble

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

full_data = pd.read_csv('https://raw.githubusercontent.com/benchang123/Ames-Housing/master/ames.csv')
training_data, test_data = train_test_split(full_data, random_state=42, test_size=0.2)

full_data.shape
# Out:
# (2000, 82)

# %% [markdown]
# ## EDA
#
# First, we will see the amount of missing data in each column and drop those that have too many to the point where it isn't meaningful to analyze them.

# %%
#Remove features with lots of NA
nanmean=training_data.isna().mean()*100
nan=nanmean[nanmean>25].sort_values(ascending=False)
print(nan)

training_data.drop(columns=nan.index,inplace=True)
# Out:
# Pool_QC         99.5000
# Misc_Feature    96.0000
# Alley           93.9375
# Fence           80.6250
# Fireplace_Qu    48.6875
# dtype: float64
# C:\Users\bench\Anaconda3\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Number of sold houses per year
year=training_data.groupby('Yr_Sold').count()['Order'].plot(kind='bar')
year
# Out:
# <AxesSubplot:xlabel='Yr_Sold'>

# %% [markdown]
# The joint plot was made to see if there are outliers. There are outliers present when the sales price is large and where the living area is greater than 500 sq. ft.

# %%
#outliers for living area vs price

training_data.columns.values

sns.jointplot(
    x='Gr_Liv_Area', 
    y='SalePrice', 
    data=training_data,
);

# %%
#2 SD for sales price

salepricemean=np.mean(training_data['SalePrice'])
salepricestd=np.std(training_data['SalePrice'])

print('Mean Sales Price: ', salepricemean)
print('STD Sales Price: ', salepricestd)

salepricerange=(salepricemean-(2*salepricestd),salepricemean+(2*salepricestd))
salepricerange
# Out:
# Mean Sales Price:  181503.679375
# STD Sales Price:  81770.00223512761
# (17963.67490474478, 345043.68384525523)

# %% [markdown]
# Upon looking at the data more, outliers exists when the Gr_Liv_Area is greater than 5,000 because they were partial sales. Therefore, it is in our interest to remove the outliers so our regression can fit more accurately.

# %%
plt.subplots(figsize=(10,8))
plt.hist(training_data['SalePrice'])
plt.xlabel("Sales Price")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#check outliers

training_data.loc[training_data['Gr_Liv_Area']>4000,['Gr_Liv_Area','SalePrice']]
# Out:
#       Gr_Liv_Area  SalePrice
# 1471         5095     190950
# 1014         5642     152200

# %%
def remove_outliers(data, variable, upper):
    return data.loc[(data[variable] < upper), :]

training_data = remove_outliers(training_data, 'Gr_Liv_Area', 4000)

# %% [markdown]
# The type of data in each variable will help determine how we will manipulate each variable.

# %%
training_data.dtypes.value_counts()
# Out:
# object     38
# int64      30
# float64     9
# dtype: int64

# %% [markdown]
# The distribution of neighborhoods in the data might give us something insightful. We see that most of the houses reside in the Ames area, which is expected.

# %%
training_data.groupby('Neighborhood').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# The correlation between the Sales Price and the numerical variables will help determine which variables to choose in our linear regression. One thing to keep in mind is colinearity within the data. This will be addressed later in the notebook.

# %%
num_cols = training_data.dtypes[(training_data.dtypes == 'int64') | (training_data.dtypes == 'float64')].index
corr_df = training_data.loc[:,num_cols].corr()

sale_price_corr = corr_df['SalePrice'].drop('SalePrice',axis=0).sort_values(ascending=False)
ax = plt.subplots(figsize=(10,15))
ax = sns.barplot(y=sale_price_corr.keys(),x=sale_price_corr.values)
plt.xlabel("Correlation")
plt.ylabel("Feature")
# Out:
# Text(0, 0.5, 'Feature')

# %% [markdown]
# There is some interesting remarks from the barplot. Intuitively, one can expect that if there are more bedrooms, the sale price will be higher. However, from creating a scatter plot, there doesn't seem to be a clear correlation.

# %%
noise = np.random.normal(0,0.5,training_data.shape[0])
training_data_2=training_data
training_data_2['Bedroom_AbvGr']=training_data_2['Bedroom_AbvGr']+noise
sns.scatterplot(data=training_data_2,x='Bedroom_AbvGr',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Bedroom_AbvGr', ylabel='SalePrice'>

# %% [markdown]
# The overall quality of the house (rated 1-10) seemed to have the highest correlation. Let's see how the scatter plot looks like.

# %%
training_data_2=training_data
training_data_2['Overall_Qual']=training_data_2['Overall_Qual']+noise
sns.scatterplot(data=training_data_2,x='Overall_Qual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Overall_Qual', ylabel='SalePrice'>

# %% [markdown]
# ## Feature Engineering
#
# We will now explore variables where feature engineering is required.
#
# Given the number of variables that show the quantity of bathrooms, we can combine it into a variable with the total number of bathrooms as:
#
# $$ \text{TotalBathrooms}=(\text{BsmtFullBath} + \text{FullBath}) + \dfrac{1}{2}(\text{BsmtHalfBath} + \text{HalfBath})$$
#
# *Idea from Data 200 Notebook

# %%
def add_total_bathrooms(data):
    with_bathrooms = data.copy()
    bath_vars = ['Bsmt_Full_Bath', 'Full_Bath', 'Bsmt_Half_Bath', 'Half_Bath']
    weights = pd.Series([1, 1, 0.5, 0.5], index=bath_vars)
    with_bathrooms['TotalBathrooms']=with_bathrooms[bath_vars].fillna(0)@weights
    return with_bathrooms

training_data = add_total_bathrooms(training_data)

# %% [markdown]
# A scatter plot was created to show there was a positive correlation between the number of total bathrooms and the sale price.

# %%
training_data_2=training_data
training_data_2['TotalBathrooms']=training_data_2['TotalBathrooms']+noise
sns.scatterplot(data=training_data_2,x='TotalBathrooms',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBathrooms', ylabel='SalePrice'>

# %%
def add_total_SF(data):
    totalSFdf = data.copy()
    totalSFdf['Total_SF'] = totalSFdf['Total_Bsmt_SF'] + totalSFdf['Gr_Liv_Area']
    return totalSFdf

training_data = add_total_SF(training_data)

# %% [markdown]
# Next, houses that are in rich neighborhoods are likely to be more expensive. From grouping the data by the neighborhoods, there are four distinct neighborhoods that have the largest sales price, followed by a small dropoff.

# %%
def find_rich_neighborhoods(data, n=3, metric=np.mean):
    neighborhoods = data.groupby('Neighborhood').agg(metric).sort_values('SalePrice',ascending=False).iloc[0:n].index.tolist()
    return neighborhoods

richhoods=training_data.groupby('Neighborhood').agg(np.mean).sort_values('SalePrice',ascending=False).iloc[0:20]
plt.subplots(figsize=(5,8))
sns.barplot(y=richhoods.index,x=richhoods.SalePrice)
plt.xticks(rotation=45)
# Out:
# (array([     0.,  50000., 100000., 150000., 200000., 250000., 300000.,
#         350000., 400000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# The following will add a one hot encoding feature of the four wealthiest neighborhood to the dataset.

# %%
def add_in_rich_neighborhood(data, neighborhoods):
    data['in_rich_neighborhood'] = data['Neighborhood'].isin(neighborhoods).astype(int)
    return data

rich_neighborhoods = find_rich_neighborhoods(training_data, 4, np.mean)
training_data = add_in_rich_neighborhood(training_data, rich_neighborhoods)

# %% [markdown]
# One hot encoding will be used for categorical variables. The following is a function that will one hot encode variables.

# %%
categorical = (training_data.dtypes == "object")
categorical_list = list(categorical[categorical].index)
print(categorical_list)

def encode(data):
    categorical = (data.dtypes == "object")
    categorical_list = list(categorical[categorical].index)
    for i in categorical_list:
        encode=preprocessing.LabelEncoder()
        data[i]=encode.fit_transform(data[i])
    return data
training_data=encode(training_data)
# Out:
# ['MS_Zoning', 'Street', 'Lot_Shape', 'Land_Contour', 'Utilities', 'Lot_Config', 'Land_Slope', 'Neighborhood', 'Condition_1', 'Condition_2', 'Bldg_Type', 'House_Style', 'Roof_Style', 'Roof_Matl', 'Exterior_1st', 'Exterior_2nd', 'Mas_Vnr_Type', 'Exter_Qual', 'Exter_Cond', 'Foundation', 'Bsmt_Qual', 'Bsmt_Cond', 'Bsmt_Exposure', 'BsmtFin_Type_1', 'BsmtFin_Type_2', 'Heating', 'Heating_QC', 'Central_Air', 'Electrical', 'Kitchen_Qual', 'Functional', 'Garage_Type', 'Garage_Finish', 'Garage_Qual', 'Garage_Cond', 'Paved_Drive', 'Sale_Type', 'Sale_Condition']

# %% [markdown]
# To lower the error of our fit, it is best to optimize the amount of variables we add to our regression model. The following will test the bounds of our cross-validation error by adding variables to our model before the cross-validation error increases (i.e. bias-variance tradeoff).
#
# The following code will only factor in numberical variables. The RMSE is plotted for each addition of a variable.
#
# The plot illustrates that the RMSE decreases up until the 15th feature. After that, the RMSE flattens out and then slightly decreases further. Therefore, choosing 10-15 variables is optimal to lower the RMSE and to prevent a low bias and high variance.
#
# *Idea from Data 200*

# %%
#Feature Importance (RF)

X=training_data.drop(columns=['SalePrice'])
Y=training_data['SalePrice']

for i in range(len(num_cols)-1):
    meanvar=np.nanmean(X[num_cols[i]])
    X[num_cols[i]].fillna(meanvar,inplace=True)

X=X.fillna(method="pad")

clf = ensemble.RandomForestClassifier()
clf = clf.fit(X, Y)
features = X.columns
importances = clf.feature_importances_
idxrf = np.argsort(importances)[::-1]

plt.figure(figsize=(15,10))
plt.bar(np.arange(len(idxrf)),importances[idxrf])
plt.xticks(range(len(idxrf)), [features[i] for i in idxrf], rotation='vertical')

plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Importance of Feature')

#number of features based on trees

features=79
rmse = np.zeros(features-1)

# loop over the Ks

train_error_vs_N = []
cv_error_vs_N = []

for i in range(1,features):
    trainingx=X.iloc[:,idxrf[0:i]]
    trainingy=Y

    linear_model=lm.LinearRegression()
    
    cv_results = cross_validate(linear_model, trainingx, trainingy, 
                                cv=5,scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(np.arange(1,features), train_error_vs_N)
sns.lineplot(np.arange(1,features), cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");
plt.title('Importance of Feature (Random Forest)')

print(cv_error_vs_N[5:15])

numfeaturesrf=20
# Out:
# [39502.45535020889, 39446.69031186077, 36913.668701621726, 35658.183581513695, 34675.02558355, 33316.34846938063, 33315.184216170215, 32882.05658412579, 32895.93851639082, 32364.15068826384]

# %%
#Feature Importance (Gradient Boosting)

clf = ensemble.GradientBoostingClassifier(n_estimators=25,verbose=3)
clf = clf.fit(X, Y)
features = X.columns
importances = clf.feature_importances_
idxgb = np.argsort(importances)[::-1]

plt.figure(figsize=(15,10))
plt.bar(np.arange(len(idxgb)),importances[idxgb])
plt.xticks(range(len(idxgb)), [features[i] for i in idxgb], rotation='vertical')

plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Importance of Feature')

#number of features based on gb

features=79
rmse = np.zeros(features-1)

# loop over the Ks

train_error_vs_N = []
cv_error_vs_N = []

for i in range(1,features):
    trainingx=X.iloc[:,idxgb[0:i]]
    trainingy=Y

    linear_model=lm.LinearRegression()
    
    cv_results = cross_validate(linear_model, trainingx, trainingy, 
                                cv=5,scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(np.arange(1,features), train_error_vs_N)
sns.lineplot(np.arange(1,features), cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");
plt.title('Importance of Feature (Gradient Boosting)')

print(cv_error_vs_N[10:20])

numfeaturesgb=20
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.4525           12.40m
#          2         386.4099           12.67m
#          3         298.5248           12.40m
#          4         297.9337           12.18m
#          5         297.6414           11.68m
#          6         297.6389           11.13m
#          7         297.6369           10.58m
#          8         297.6354           10.03m
#          9         297.6341            9.43m
#         10         297.6331            8.83m
#         11         297.6323            8.24m
#         12         297.6317            7.65m
#         13         297.6312            7.06m
#         14         297.6307            6.48m
#         15         297.6304            5.94m
#         16         297.6301            5.37m
#         17         297.6298            4.79m
#         18         297.6296            4.21m
#         19         297.6295            3.61m
#         20         297.6294            3.02m
#         21         297.6292            2.42m
#         22         297.6292            1.82m
#         23         297.6291            1.21m
#         24         297.6290           36.42s
#         25         297.6290            0.00s
# [35624.340391444115, 35624.71278985521, 35565.57150823005, 34235.74518527668, 34231.945489203594, 34142.40986222825, 33462.45949079332, 33362.291224303364, 32456.469975019827, 32006.451251302882]

# %%
#number of features based on corr

train_error_vs_N = []
cv_error_vs_N = []
linear_model=lm.LinearRegression()

num_cols = training_data.dtypes[(training_data.dtypes == 'int64') | (training_data.dtypes == 'float64')].index
corr_df = training_data.loc[:,num_cols].corr()
sale_price_corr = corr_df['SalePrice'].drop('SalePrice',axis=0).sort_values(ascending=False)

range_of_num_features = range(1, sale_price_corr.shape[0] + 1)

for N in range_of_num_features:
    sale_price_corr_first_N_features = sale_price_corr.iloc[:N]
    saleprice=training_data['SalePrice'].drop(training_data.index
                                              [training_data[sale_price_corr.iloc[:N].index]
                                               .isnull().any(1)])
    indepVar=training_data[sale_price_corr_first_N_features.index].dropna()
    
    scaler=preprocessing.StandardScaler()
    indepVar = pd.DataFrame(scaler.fit_transform(indepVar),columns = indepVar.columns)
    
    cv_results = cross_validate(linear_model, indepVar, saleprice, cv=4,
                                scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(range_of_num_features, train_error_vs_N)
sns.lineplot(range_of_num_features, cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");

# %% [markdown]
# Further illustration shows exactly where the dip occurs before the RMSE rises again. The valley seems to occur on the 14th variable.

# %%
print(cv_error_vs_N[10:20])

numfeaturescorr=16
# Out:
# [34907.011997783375, 34806.40265939595, 33825.38373505886, 33815.25543336937, 33414.67812637586, 32179.695050007478, 32650.188168645138, 32738.947161859902, 32605.121326609442, 32631.754472492576]

# %% [markdown]
# From the 14 variables, it is important to take out variables that are dependent on each other. A heat map with the correlation between the variables were made.
#
# For example, the amount of cars you can fit into a garage is highly correlated to the garage area, which makes sense. Therefore, we need to delete one of the variables.

# %%
#multicorr test

features=sale_price_corr.iloc[:numfeaturescorr]

plt.figure(figsize=(10,10))
sns.heatmap(training_data[features.index].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From observing the heat map, there were 5 variables that I decided to take out to minimize multicollinearity.

# %%
colinear=['TotRms_AbvGrd','Garage_Area','Year_Remod/Add','Full_Bath','Garage_Yr_Blt']

idxcorr=[]

for i in range(len(features.index.to_list())):
    idxcorr.append(training_data.columns.get_loc(sale_price_corr.index.to_list()[i]))
idxcorr.insert(0,76)
idxcorr=np.array(idxcorr)

# %% [markdown]
# ## Modeling

# %% [markdown]
# We will define our pipeline to create the dataframe that will be passed into the regression models.
#
# *Idea from Data 200*

# %%
def select_columns(data, columns):
    """Select only columns passed as arguments."""
    return data.iloc[:, columns]

def process_data_fm(data, overall_features):
    data = remove_outliers(data, 'Gr_Liv_Area', 4000)
    data = add_total_bathrooms(data)
    
    # Transform Data, Select Features
    data = add_in_rich_neighborhood(data, rich_neighborhoods)
    data = select_columns(data, overall_features)
        
    # Return predictors and response variables separately
    X = data.drop(['SalePrice'], axis = 1)
    
    numf=X.dtypes[(X.dtypes == 'int64') | (X.dtypes == 'float64')].index
    scaler=preprocessing.StandardScaler()
    X.loc[:,numf] = scaler.fit_transform(X.loc[:,numf])
    X = encode(X)
    
    y = data.loc[:, 'SalePrice']
    X=X.fillna(method="pad")
    X=X.fillna(method="bfill")
    return X, y

# %% [markdown]
# ### Ordinary Least Square

# %% [markdown]
# The first type of regression that will be conducted is the ordinary least square.
#
# The data was read in again and if there is no data in any of the 14 numerical columns we chose, the observation was removed. The data was then split into the test and training data.

# %%
def OLSrun(X_train_n, y_train, X_test_n, y_test):  

    final_model = lm.LinearRegression()
    final_model.fit(X_train_n, y_train)
    y_predicted_train = final_model.predict(X_train_n)
    y_predicted_test = final_model.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_predicted_train, y_train,squared=False)
    test_rmse = metrics.mean_squared_error(y_predicted_test, y_test,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    #Line Plot
    plt.figure(figsize=(10,7))
    ax=sns.scatterplot(y_predicted_train,y_train,label="Training")
    sns.scatterplot(y_predicted_test,y_test,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_predicted_train,y_train,label="Training")
    sns.residplot(y_predicted_test,y_test,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()

# %% [markdown]
# Only 19 rows were removed out of 2,000, which won't affect our analysis.

# %% [markdown]
# Both the training and test data will be processed into our pipeline that we defined earlier.

# %% [markdown]
# The training data was fitted into our linear regression model and from that the predicted training and test sales prices was determined.

# %% [markdown]
# The RMSE of the test and training dataset was calculated.

# %% [markdown]
# A residual plot of the RMSE and Predicted Sales Price shows that in general the regression was fine except for predicted sales price greater than 40,000, where there is a large absolute RMSE.

# %% [markdown]
# The predicted and actual sales price for the test dataset is plotted. There are a few outliers above the true sales price of 500,000.

# %% [markdown]
# ### Ridge Regression
#
# The second type of regression that will be implemented is the ridge regression. Since the regularization parameter depends on the coefficents of our regression, the data has to be standardized to prevent one feature from being overrepresented.

# %%
def ridgerun(X_train_n, y_train_n, X_test_n, y_test_n):
    
    param_grid = {'alpha': [0.01, 0.1, 1., 5., 10., 25., 50., 100.]}
    final_ridge = GridSearchCV(lm.Ridge(), cv=5, param_grid=param_grid, scoring='neg_mean_squared_error')
    final_ridge.fit(X_train_n, y_train_n)
    alpha = final_ridge.best_params_['alpha']
    print('Initial Best Alpha', alpha)
    
    param_gridimp = {'alpha': list(np.linspace(alpha-(alpha*0.2),alpha+(alpha*0.2),200))}
    final_ridgeimp = GridSearchCV(lm.Ridge(), cv=5, param_grid=param_gridimp, scoring='neg_mean_squared_error')
    final_ridgeimp.fit(X_train_n, y_train_n)
    alphaimp = final_ridgeimp.best_params_['alpha']
    print('Improved Best Alpha', round(alphaimp,2))
    
    
    y_ridge_train = final_ridgeimp.predict(X_train_n)
    y_ridge_test = final_ridgeimp.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_ridge_train, y_train_n,squared=False)
    test_rmse = metrics.mean_squared_error(y_ridge_test, y_test_n,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    
    #Line Plot
    plt.figure(figsize=(10,7))
    
    ax=sns.scatterplot(y_ridge_train,y_train_n,label="Training")
    sns.scatterplot(y_ridge_test,y_test_n,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_ridge_train,y_train_n,label="Training")
    sns.residplot(y_ridge_test,y_test_n,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()
    
    #Feature Importance
    ridge=final_ridgeimp.best_estimator_
    
    coefs = pd.DataFrame({'coefs':ridge.coef_}, index=X_train_n.columns)
    coefs['coefs_abs'] = np.abs(coefs.coefs)
    
    top_coefs = coefs.sort_values('coefs_abs', ascending=False).head(10)
    plt.figure(figsize=(8,10))
    sns.barplot( top_coefs.coefs_abs, top_coefs.index)
    plt.title('Ridge Regression: Top Features')
    plt.xlabel('Absolute Coefficient')
    plt.show()

# %% [markdown]
# First, the optimal hyperparameter needs to be found for the regression.

# %% [markdown]
# From determining best alpha, we can further refine the searching on what the best alpha should be.

# %% [markdown]
# The predicted sales price can then be determined from fitting the model.

# %% [markdown]
# A residual plot was then made. Here we can see that the same issue as the ordinary least squares regression where at around 2.1, there is a large absolute RMSE.

# %% [markdown]
# The same shows in our scatter plot of the predicted and actual sales price. There are four clear outliers where the sales price was underestimated.

# %% [markdown]
# ### Lasso Regression
#
# The third type of regression that will be implemented is the lasso regression. We will use the standardized data for the same reason as the ridge regression.

# %%
def lassorun(X_train_n, y_train_n, X_test_n, y_test_n):  

    param_grid = {'alpha': [0.01, 0.1, 1., 5., 10., 25., 50., 100., 500., 1000.]}
    final_lasso = GridSearchCV(lm.Lasso(), cv=5, param_grid=param_grid, scoring='neg_mean_squared_error')
    final_lasso.fit(X_train_n, y_train_n)
    alpha = final_lasso.best_params_['alpha']
    print('Initial Best Alpha', alpha)
    
    param_gridimp = {'alpha': list(np.linspace(alpha-(alpha*0.2),alpha+(alpha*0.2),1000))}
    final_lassoimp = GridSearchCV(lm.Lasso(), cv=5, param_grid=param_gridimp, scoring='neg_mean_squared_error')
    final_lassoimp.fit(X_train_n, y_train_n)
    alphaimp = final_lassoimp.best_params_['alpha']
    print('Improved Best Alpha', round(alphaimp,2))
    
    y_lasso_train = final_lassoimp.predict(X_train_n)
    y_lasso_test = final_lassoimp.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_lasso_train, y_train_n,squared=False)
    test_rmse = metrics.mean_squared_error(y_lasso_test, y_test_n,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    
    #Line Plot
    plt.figure(figsize=(10,7))

    ax=sns.scatterplot(y_lasso_train,y_train_n,label="Training")
    sns.scatterplot(y_lasso_test,y_test_n,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_lasso_train,y_train_n,label="Training")
    sns.residplot(y_lasso_test,y_test_n,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()
    
    #Feature Importance
    lasso=final_lassoimp.best_estimator_
    
    coefs = pd.DataFrame({'coefs':lasso.coef_}, index=X_train_n.columns)
    coefs['coefs_abs'] = np.abs(coefs.coefs)
    
    top_coefs = coefs.sort_values('coefs_abs', ascending=False).head(10)
    plt.figure(figsize=(8,10))
    sns.barplot( top_coefs.coefs_abs, top_coefs.index)
    plt.title('LASSO Regression: Top Features')
    plt.xlabel('Absolute Coefficient')
    plt.show()

# %% [markdown]
# We see that the lack of a hyperparameter is optimal for the lasso regression, which means that there is not enough features where a regularization parameter would help reduce the error.

# %% [markdown]
# The predicted sales price is then determined.

# %% [markdown]
# A residual plot was then made and the same pattern is seen as the ridge regression.

# %% [markdown]
# The same pattern shows in our scatter plot as the ridge regression where there are four clear outliers where the sales price was underestimated.

# %%
def runmodels(training_data, test_data, numfeatures, idx):
    training_data = add_total_SF(training_data)
    test_data = add_total_SF(test_data)
    
    X_train, y_train=process_data_fm(training_data,idx[0:numfeatures])
    X_test, y_test=process_data_fm(test_data,idx[0:numfeatures])
    
    X_train_r2 = sm.add_constant(X_train)
    models = sm.OLS(y_train,X_train_r2)
    results = models.fit()
    print(results.summary())
    
    X_train_n = X_train
    X_test_n = X_test
    
    OLSrun(X_train_n, y_train, X_test_n, y_test)
    ridgerun(X_train_n, y_train, X_test_n, y_test)
    lassorun(X_train_n, y_train, X_test_n, y_test)

# %%
##### Running each model ########

full_data = pd.read_csv('https://raw.githubusercontent.com/benchang123/Ames-Housing/master/ames.csv')

#drop too many nan
nan=nanmean[nanmean>25].sort_values(ascending=False)
full_data.drop(columns=nan.index,inplace=True)

training_data, test_data = train_test_split(full_data, random_state=42, test_size=0.2)

training_data.shape
# Out:
# (1600, 77)

# %%
#RF
runmodels(training_data, test_data, numfeaturesrf, idxrf)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     494.6
# Date:                Wed, 21 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:47:55   Log-Likelihood:                -18795.
# No. Observations:                1598   AIC:                         3.763e+04
# Df Residuals:                    1578   BIC:                         3.774e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.815e+05    781.027    232.392      0.000     1.8e+05    1.83e+05
# PID             -793.3976    862.820     -0.920      0.358   -2485.792     898.997
# Overall_Qual    2.461e+04   1294.893     19.009      0.000    2.21e+04    2.72e+04
# Order           1340.0998    809.075      1.656      0.098    -246.876    2927.075
# Bedroom_AbvGr  -9911.0387   1046.139     -9.474      0.000    -1.2e+04   -7859.070
# Gr_Liv_Area     1.985e+04   3.24e+04      0.612      0.541   -4.38e+04    8.35e+04
# Lot_Area        5996.5367    860.483      6.969      0.000    4308.726    7684.347
# 1st_Flr_SF      2418.2220   1431.101      1.690      0.091    -388.837    5225.281
# Total_SF        2.047e+04   5.08e+04      0.403      0.687   -7.91e+04     1.2e+05
# Bsmt_Unf_SF     -199.4078   2245.835     -0.089      0.929   -4604.542    4205.726
# Garage_Area     7946.8772   1052.744      7.549      0.000    5881.954       1e+04
# Total_Bsmt_SF  -1397.6990   2.79e+04     -0.050      0.960   -5.61e+04    5.33e+04
# Lot_Frontage    3573.6360    886.360      4.032      0.000    1835.068    5312.204
# Mo_Sold         -230.5939    797.512     -0.289      0.773   -1794.889    1333.701
# Garage_Yr_Blt   -481.8207   1375.065     -0.350      0.726   -3178.968    2215.326
# Year_Built      5963.8764   1463.013      4.076      0.000    3094.223    8833.529
# BsmtFin_SF_1    1.135e+04   2344.016      4.840      0.000    6747.852    1.59e+04
# Year_Remod/Add  6813.5223   1123.301      6.066      0.000    4610.202    9016.842
# Wood_Deck_SF     708.5822    833.498      0.850      0.395    -926.298    2343.462
# Open_Porch_SF    203.9631    854.571      0.239      0.811   -1472.251    1880.178
# ==============================================================================
# Omnibus:                      437.004   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3101.836
# Skew:                           1.085   Prob(JB):                         0.00
# Kurtosis:                       9.471   Cond. No.                         205.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 31022.35 29872.12
# Initial Best Alpha 50.0
# Improved Best Alpha 60.0
# Training and Test Error: 31069.98 29598.0
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 605973489181.2919, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 644032286917.0626, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 600642550249.7477, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 605861127193.7156, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4615740900.161499, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 562111850744.5076, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 584408660512.2261, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 550297148492.0529, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 549453391454.1963, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4617389700.6328125, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 260798589880.35455, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235050919663.30396, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224217699478.89917, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212191974228.1889, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4633827740.534546, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55828235312.342285, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45259474106.023926, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43238698312.29028, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39674723549.41614, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4705794564.520752, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24837087890.3114, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20433720565.32422, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19221387958.380615, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17863450404.45862, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4793247592.285278, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2768146011.0632324, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8779192193.782227, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7998271465.942749, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7729633123.324707, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5038903327.67688, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5393084043.256714, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 1000.0
# Improved Best Alpha 928.13
# Training and Test Error: 31137.11 29586.72

# %%
#GB
runmodels(training_data, test_data, numfeaturesgb, idxgb)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     473.9
# Date:                Wed, 21 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:48:29   Log-Likelihood:                -18824.
# No. Observations:                1598   AIC:                         3.769e+04
# Df Residuals:                    1578   BIC:                         3.780e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.81e+05   2960.871     61.135      0.000    1.75e+05    1.87e+05
# Order          1086.2991    813.491      1.335      0.182    -509.337    2681.936
# PID           -1096.2320    860.211     -1.274      0.203   -2783.509     591.045
# Open_Porch_SF   638.8558    867.017      0.737      0.461   -1061.771    2339.483
# Gr_Liv_Area    -372.3843   3.43e+04     -0.011      0.991   -6.77e+04    6.69e+04
# Bedroom_AbvGr -1.119e+04   1164.682     -9.604      0.000   -1.35e+04   -8900.679
# 1st_Flr_SF      1.55e+04   7339.318      2.111      0.035    1099.166    2.99e+04
# Overall_Qual   2.773e+04   1259.024     22.025      0.000    2.53e+04    3.02e+04
# Total_Bsmt_SF -1922.8639   2.85e+04     -0.068      0.946   -5.77e+04    5.39e+04
# Lot_Area       6030.5800    876.982      6.877      0.000    4310.408    7750.753
# Electrical      146.4471    780.302      0.188      0.851   -1384.090    1676.985
# Total_SF       2.179e+04   5.18e+04      0.421      0.674   -7.98e+04    1.23e+05
# 2nd_Flr_SF     1.468e+04   7940.994      1.848      0.065    -900.384    3.03e+04
# BsmtFin_SF_1   1.178e+04   2387.666      4.933      0.000    7095.474    1.65e+04
# Bsmt_Unf_SF    -156.8138   2288.344     -0.069      0.945   -4645.328    4331.701
# TotRms_AbvGrd  3534.4371   1556.614      2.271      0.023     481.188    6587.686
# Lot_Frontage   3451.4465    906.070      3.809      0.000    1674.219    5228.674
# Wood_Deck_SF   1298.6010    847.919      1.532      0.126    -364.565    2961.767
# Garage_Area    8073.8390   1071.304      7.536      0.000    5972.509    1.02e+04
# Garage_Yr_Blt  6341.0486   1040.704      6.093      0.000    4299.741    8382.356
# ==============================================================================
# Omnibus:                      345.265   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2226.798
# Skew:                           0.847   Prob(JB):                         0.00
# Kurtosis:                       8.530   Cond. No.                         336.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 31594.94 30320.86
# Initial Best Alpha 100.0
# Improved Best Alpha 80.4
# Training and Test Error: 31655.93 29867.8
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 629253097594.7712, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 675052294276.5428, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 622886745453.4326, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 636161726622.5593, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 531215261139.0277, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 615430097595.8926, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 659889761000.4333, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 608594517344.3901, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621961327774.8276, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 239737744959.35522, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 492449320335.785, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 525556074745.83545, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 481292127664.63794, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495402273174.60706, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145919153824.09338, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99969775311.68213, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110111024509.82764, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92968834572.50012, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107859933858.224, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136318015449.84998, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34902452471.70178, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33625787624.095825, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34420937227.62927, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36831781529.39258, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11081221142.592407, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11181781969.666016, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10731948557.849121, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11010537548.947021, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11568575938.26831, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3915187666.5041504, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6308921121.857178, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6246889052.754395, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6112996615.424072, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6460043494.702637, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4016331144.553955, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4559961920.789307, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 1000.0
# Improved Best Alpha 800.0
# Training and Test Error: 31733.47 30023.35

# %%
#corr
runmodels(training_data, test_data, numfeaturescorr, idxcorr)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     569.1
# Date:                Wed, 21 Apr 2021   Prob (F-statistic):               0.00
# Time:                        20:49:07   Log-Likelihood:                -18862.
# No. Observations:                1598   AIC:                         3.776e+04
# Df Residuals:                    1582   BIC:                         3.784e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.815e+05    813.430    223.167      0.000     1.8e+05    1.83e+05
# TotalBathrooms  9843.2472   1338.495      7.354      0.000    7217.837    1.25e+04
# Overall_Qual     2.34e+04   1357.354     17.240      0.000    2.07e+04    2.61e+04
# Gr_Liv_Area     3401.6286   3.38e+04      0.101      0.920   -6.28e+04    6.96e+04
# Total_Bsmt_SF  -6960.5991   2.89e+04     -0.241      0.810   -6.37e+04    4.98e+04
# 1st_Flr_SF      8332.2174   1454.137      5.730      0.000    5479.980    1.12e+04
# Garage_Cars     -137.9415   1963.039     -0.070      0.944   -3988.373    3712.490
# Garage_Area     9782.8979   1883.834      5.193      0.000    6087.825    1.35e+04
# Year_Built      4484.1621   1571.665      2.853      0.004    1401.396    7566.928
# Total_SF        3.253e+04   5.28e+04      0.616      0.538    -7.1e+04    1.36e+05
# Year_Remod/Add  8818.0263   1168.570      7.546      0.000    6525.917    1.11e+04
# Full_Bath       -1.03e+04   1357.751     -7.587      0.000    -1.3e+04   -7637.938
# Garage_Yr_Blt    744.4129   1443.841      0.516      0.606   -2087.630    3576.456
# Mas_Vnr_Area    7652.4608    941.053      8.132      0.000    5806.619    9498.303
# TotRms_AbvGrd  -1261.2798   1452.872     -0.868      0.385   -4111.036    1588.476
# Fireplaces      5266.1196    980.011      5.374      0.000    3343.862    7188.377
# ==============================================================================
# Omnibus:                      412.075   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2327.635
# Skew:                           1.083   Prob(JB):                         0.00
# Kurtosis:                       8.502   Cond. No.                         230.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 32351.07 31022.36
# Initial Best Alpha 10.0
# Improved Best Alpha 12.0
# Training and Test Error: 32354.98 30963.95
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 671180167120.9866, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 695142332987.9099, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 656019009172.0787, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 666419079381.2288, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224965968025.24164, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 659431507327.3188, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 683610996305.0896, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 644284122132.6177, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 654698398269.8748, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 224983962976.25385, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 552535945878.5364, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 578302128458.5383, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 537197412494.3231, tolerance: 821774594.2901274
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547840610236.7697, tolerance: 870246775.196574
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225157460795.885, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192519560030.359, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225786648360.0102, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90773030376.0592, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7968903345.223877, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30749971316.700317, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8356743322.208984, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8945015098.614502, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9904564884.546143, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 100.0
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9555676674.575195, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9556467022.594238, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9557093409.751953, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9557676314.493652, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9558258871.689697, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9558841081.33667, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9559422943.435791, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9560189648.39209, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9560977998.212402, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9561766206.941162, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9562554274.621826, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9563342201.2146, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9564129986.730713, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9564917631.18457, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9565705134.5542, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9566492496.853027, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9567279718.087402, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9568066798.235352, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 907918145.748291, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9568853737.322021, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 933170888.9230957, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9569640535.328857, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 959895706.3898926, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9570427192.266357, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 988078553.0715332, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9571213708.128418, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1012885834.848877, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9572000082.917969, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1031896893.4711914, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9572786316.623291, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1051818093.0495605, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9573525501.656982, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1072641965.720459, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9574104409.661377, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1086597192.239746, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9574682971.913818, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1096157211.9956055, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9575261188.44629, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1106146696.0546875, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9575839059.22705, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1116562814.1850586, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9576461816.204102, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1117717210.2504883, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9577246037.055176, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1116638194.1516113, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9578030116.323486, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1115693184.709961, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9578814054.018066, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1112690627.958496, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9579597850.134521, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1085835721.3078613, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9580381504.65918, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1049524766.0507812, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9581165017.615723, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1003559880.9360352, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9581948388.987549, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 945528228.8942871, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9582731618.788574, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9583514707.00293, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9584297653.644775, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9585080458.697021, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9585863122.184814, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9586645644.08252, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9587428024.401123, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9588210263.142822, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9588992360.302734, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9589774315.897217, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9590525772.976807, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9591100419.706055, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9591674722.495361, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9592248681.345215, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9592822296.26587, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9593400425.080566, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9594180352.6333, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9594960138.09082, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9595739781.466553, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9596519282.763916, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9597298641.967773, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9598077859.09253, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9598856934.132812, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9599635867.086182, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9600414657.953613, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9601193306.74121, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9601971813.439209, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9602750178.05249, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9603528400.58789, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9604306481.03711, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9605084419.392578, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9605862215.667236, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9606639869.864258, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9607417381.970459, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9608084303.359375, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9608654429.671875, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9609224213.858887, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9609793655.905518, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9610362755.826416, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9610991792.61499, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9611767261.006836, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9612542586.812012, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9613317770.018066, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9614092810.64209, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9614867708.670898, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9615642464.112305, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9616417076.967285, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9617191547.22461, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9617965874.891602, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9618740059.9729, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9619514102.45288, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9620288002.351807, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9621061759.662354, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9621835374.376709, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9622608846.504639, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9623382176.0354, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9624155362.987305, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9624928407.33545, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9625624956.920654, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9626190649.422607, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9626756001.608154, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9627321013.468018, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9627885685.001465, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9628450682.618164, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9629221667.57251, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9629992509.446777, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9630763208.211426, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9631533763.889648, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9632304176.468262, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9633074445.95044, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9633844572.332764, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9634614555.62085, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9635384395.810791, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9636154092.913574, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9636923646.913818, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9637693057.818848, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9638462325.6167, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9639231450.337402, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9640000431.954346, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9640769270.468262, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9641537965.894775, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9642306518.219482, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9643074927.453125, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9643712196.831543, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9644273203.619629, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9644833871.892334, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9645394201.646973, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9645954192.868164, tolerance: 859516305.1975329
#   positive)
# ...
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9930905506.029541, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9931388457.102295, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9931871094.906738, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9932353419.445312, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9932835430.730713, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9933317128.748291, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9933798513.516357, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9934279585.01001, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9934938056.716309, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9935625617.3479, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9936313027.283936, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9937000286.544434, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9937687395.12378, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9938374353.02124, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9939061160.237549, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9939747816.76538, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9940434322.614746, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9941120677.783203, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9941806882.26709, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9942492936.073486, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9943178839.197266, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9943864591.635742, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9944550193.393555, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9907566018.258545, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9799166153.930908, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9691597970.642334, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9575984378.831543, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9389394816.807617, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9204572140.074219, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9021528875.358398, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8786537369.401367, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8546074987.409912, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8308485026.394775, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8044938861.48584, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7767195294.004883, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7493459761.929932, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7106474169.879639, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6462930431.709473, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5817719018.530273, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5192863679.559814, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4592698157.480225, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4031857092.805176, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3510737973.5410156, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3030526349.620117, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2644004962.7165527, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2460151343.2058105, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2289972839.0493164, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2129886742.3933105, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1974480305.9033203, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1828123144.1594238, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1695256252.4091797, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1566388566.4001465, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1441787965.328125, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1333421763.5134277, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1228371892.9626465, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1126666602.446289, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1036294188.0849609, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 951964789.2988281, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 870327403.2788086, tolerance: 859516305.1975329
#   positive)
# Improved Best Alpha 120.0
# Training and Test Error: 32356.02 30965.13

# %% [markdown]
# # Conclusion
#
# In the end, we determined that using 9 numberical variables was optimal for our regression. A few categorical variables were added that would intuitively correlate to the sales price and improve our model.
#
# Areas of improvement for our model including trying to find a method that determines the best categorical variables to use, as only three were used in this notebook. Adding more categorical variables that are highly correlated to the sales price would help fit our data better to our chosen model and reduce test errors. It would also be helpful to further address a few outliers which was throwing off our regression. Perhaps using a different type of model would help accrurately predict the sales price of houses.
