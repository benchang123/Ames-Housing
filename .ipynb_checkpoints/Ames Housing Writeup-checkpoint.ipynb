# %% [markdown]
# # Ames Housing Prices
#
# ## Purpose of the Analysis:
#
# ### Find out which Variables Strongly Affect the Housing Prices
#
# The goal of this project is to determine which variables most strongly correlate to the housing prices in Ames, Iowa. The parts of the notebook is split into the EDA, Feature Engineering, and Modeling where regression will be conducted. Three types of regression will be conducted (Ordinary Least Square, Ridge Regression, and Lasso Regression). The root means squared error will be used to determine the training error, cross validation error, and test error.
#
# The file codebook.txt in the repository gives a description of what each independent variable is in the data.
#
# Some of the ideas presented in this project comes from the Data 200 course at UC Berkeley. The link to the course is here: http://www.ds100.org/su20/

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn import linear_model as lm
from sklearn import preprocessing
from sklearn import metrics
from sklearn import ensemble

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

full_data = pd.read_csv('https://raw.githubusercontent.com/benchang123/Ames-Housing/master/ames.csv')
training_data, test_data = train_test_split(full_data, random_state=42, test_size=0.2)

full_data.shape
# Out:
# (2000, 82)

# %% [markdown]
# ## EDA
#
# First, we will see the amount of missing data in each column and drop those that have too many to the point where it isn't meaningful to analyze them.

# %%
#Remove features with lots of NA
nanmean=training_data.isna().mean()*100
nan=nanmean[nanmean>25].sort_values(ascending=False)
print(nan)

training_data.drop(columns=nan.index,inplace=True)
# Out:
# Pool_QC         99.5000
# Misc_Feature    96.0000
# Alley           93.9375
# Fence           80.6250
# Fireplace_Qu    48.6875
# dtype: float64
# C:\Users\bench\Anaconda3\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# The joint plot was made to see if there are outliers. There are outliers present when the sales price is large and where the living area is greater than 500 sq. ft.

# %%
#outliers for living area vs price

training_data.columns.values

sns.jointplot(
    x='Gr_Liv_Area', 
    y='SalePrice', 
    data=training_data,
);

# %%
#2 SD for sales price

salepricemean=np.mean(training_data['SalePrice'])
salepricestd=np.std(training_data['SalePrice'])

print('Mean Sales Price: ', salepricemean)
print('STD Sales Price: ', salepricestd)

salepricerange=(salepricemean-(2*salepricestd),salepricemean+(2*salepricestd))
salepricerange
# Out:
# Mean Sales Price:  181503.679375
# STD Sales Price:  81770.00223512761
# (17963.67490474478, 345043.68384525523)

# %% [markdown]
# Upon looking at the data more, outliers exists when the Gr_Liv_Area is greater than 5,000 because they were partial sales. Therefore, it is in our interest to remove the outliers so our regression can fit more accurately.

# %%
plt.figure(figsize=(10,5))
sns.histplot(training_data, x='SalePrice')
plt.xlabel("Sales Price")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#check outliers

training_data.loc[training_data['Gr_Liv_Area']>4000,['Gr_Liv_Area','SalePrice']]
# Out:
#       Gr_Liv_Area  SalePrice
# 1471         5095     190950
# 1014         5642     152200

# %%
def remove_outliers(data, variable, upper):
    return data.loc[(data[variable] < upper), :]

training_data = remove_outliers(training_data, 'Gr_Liv_Area', 4000)

# %% [markdown]
# The type of data in each variable will help determine how we will manipulate each variable.

# %%
training_data.dtypes.value_counts()
# Out:
# object     38
# int64      30
# float64     9
# dtype: int64

# %% [markdown]
# The distribution of neighborhoods in the data might give us something insightful. We see that most of the houses reside in the Ames area, which is expected.

# %%
training_data.groupby('Neighborhood').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# The correlation between the Sales Price and the numerical variables will help determine which variables to choose in our linear regression. One thing to keep in mind is colinearity within the data. This will be addressed later in the notebook.

# %%
num_cols = training_data.dtypes[(training_data.dtypes == 'int64') | (training_data.dtypes == 'float64')].index
corr_df = training_data.loc[:,num_cols].corr()

sale_price_corr = corr_df['SalePrice'].drop('SalePrice',axis=0).sort_values(ascending=False)
ax = plt.subplots(figsize=(10,15))
ax = sns.barplot(y=sale_price_corr.keys(),x=sale_price_corr.values)
plt.xlabel("Correlation")
plt.ylabel("Feature")
# Out:
# Text(0, 0.5, 'Feature')

# %% [markdown]
# There is some interesting remarks from the barplot. Intuitively, one can expect that if there are more bedrooms, the sale price will be higher. However, from creating a scatter plot, there doesn't seem to be a clear correlation.

# %%
noise = np.random.normal(0,0.5,training_data.shape[0])
training_data_2=training_data
training_data_2['Bedroom_AbvGr']=training_data_2['Bedroom_AbvGr']+noise
sns.scatterplot(data=training_data_2,x='Bedroom_AbvGr',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Bedroom_AbvGr', ylabel='SalePrice'>

# %% [markdown]
# The overall quality of the house (rated 1-10) seemed to have the highest correlation. Let's see how the scatter plot looks like.

# %%
training_data_2=training_data
training_data_2['Overall_Qual']=training_data_2['Overall_Qual']+noise
sns.scatterplot(data=training_data_2,x='Overall_Qual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Overall_Qual', ylabel='SalePrice'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(training_data, x='Year_Built')
plt.xlabel('Year Built')
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Feature Engineering
#
# We will now explore variables where feature engineering is required.
#
# Given the number of variables that show the quantity of bathrooms, we can combine it into a variable with the total number of bathrooms as:
#
# $$ \text{TotalBathrooms}=(\text{BsmtFullBath} + \text{FullBath}) + \dfrac{1}{2}(\text{BsmtHalfBath} + \text{HalfBath})$$
#
# *Idea from Data 200 Notebook

# %%
def add_total_bathrooms(data):
    with_bathrooms = data.copy()
    bath_vars = ['Bsmt_Full_Bath', 'Full_Bath', 'Bsmt_Half_Bath', 'Half_Bath']
    weights = pd.Series([1, 1, 0.5, 0.5], index=bath_vars)
    with_bathrooms['TotalBathrooms']=with_bathrooms[bath_vars].fillna(0)@weights
    return with_bathrooms

training_data = add_total_bathrooms(training_data)

# %% [markdown]
# A scatter plot was created to show there was a positive correlation between the number of total bathrooms and the sale price.

# %%
training_data_2=training_data
training_data_2['TotalBathrooms']=training_data_2['TotalBathrooms']+noise
sns.scatterplot(data=training_data_2,x='TotalBathrooms',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBathrooms', ylabel='SalePrice'>

# %%
def add_total_SF(data):
    totalSFdf = data.copy()
    totalSFdf['Total_SF'] = totalSFdf['Total_Bsmt_SF'] + totalSFdf['Gr_Liv_Area']
    return totalSFdf

training_data = add_total_SF(training_data)

# %%
plt.figure(figsize=(10,5))
sns.histplot(training_data, x='Total_SF')
plt.xlabel('Total Square Feet')
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Next, houses that are in rich neighborhoods are likely to be more expensive. From grouping the data by the neighborhoods, there are four distinct neighborhoods that have the largest sales price, followed by a small dropoff.

# %%
def find_rich_neighborhoods(data, n=3, metric=np.mean):
    neighborhoods = data.groupby('Neighborhood').agg(metric).sort_values('SalePrice',ascending=False).iloc[0:n].index.tolist()
    return neighborhoods

richhoods=training_data.groupby('Neighborhood').agg(np.mean).sort_values('SalePrice',ascending=False).iloc[0:20]
plt.subplots(figsize=(5,8))
sns.barplot(y=richhoods.index,x=richhoods.SalePrice)
plt.xticks(rotation=45)
# Out:
# (array([     0.,  50000., 100000., 150000., 200000., 250000., 300000.,
#         350000., 400000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# The following will add a one hot encoding feature of the four wealthiest neighborhood to the dataset.

# %%
def add_in_rich_neighborhood(data, neighborhoods):
    data['in_rich_neighborhood'] = data['Neighborhood'].isin(neighborhoods).astype(int)
    return data

rich_neighborhoods = find_rich_neighborhoods(training_data, 4, np.mean)
training_data = add_in_rich_neighborhood(training_data, rich_neighborhoods)

# %% [markdown]
# One hot encoding will be used for categorical variables. The following is a function that will one hot encode variables.

# %%
categorical = (training_data.dtypes == "object")
categorical_list = list(categorical[categorical].index)
print(categorical_list)

def encode(data):
    categorical = (data.dtypes == "object")
    categorical_list = list(categorical[categorical].index)
    for i in categorical_list:
        encode=preprocessing.LabelEncoder()
        data[i]=encode.fit_transform(data[i])
    return data
training_data=encode(training_data)
# Out:
# ['MS_Zoning', 'Street', 'Lot_Shape', 'Land_Contour', 'Utilities', 'Lot_Config', 'Land_Slope', 'Neighborhood', 'Condition_1', 'Condition_2', 'Bldg_Type', 'House_Style', 'Roof_Style', 'Roof_Matl', 'Exterior_1st', 'Exterior_2nd', 'Mas_Vnr_Type', 'Exter_Qual', 'Exter_Cond', 'Foundation', 'Bsmt_Qual', 'Bsmt_Cond', 'Bsmt_Exposure', 'BsmtFin_Type_1', 'BsmtFin_Type_2', 'Heating', 'Heating_QC', 'Central_Air', 'Electrical', 'Kitchen_Qual', 'Functional', 'Garage_Type', 'Garage_Finish', 'Garage_Qual', 'Garage_Cond', 'Paved_Drive', 'Sale_Type', 'Sale_Condition']

# %% [markdown]
# To lower the error of our fit, it is best to optimize the amount of variables we add to our regression model. The following will test the bounds of our cross-validation error by adding variables to our model before the cross-validation error increases (i.e. bias-variance tradeoff).
#
# The following code will only factor in numberical variables. The RMSE is plotted for each addition of a variable.
#
# The plot illustrates that the RMSE decreases up until the 15th feature. After that, the RMSE flattens out and then slightly decreases further. Therefore, choosing 10-15 variables is optimal to lower the RMSE and to prevent a low bias and high variance.
#
# *Idea from Data 200*

# %%
#Feature Importance (RF)

X=training_data.drop(columns=['SalePrice'])
Y=training_data['SalePrice']

for i in range(len(num_cols)-1):
    meanvar=np.nanmean(X[num_cols[i]])
    X[num_cols[i]].fillna(meanvar,inplace=True)

X=X.fillna(method="pad")

clf = ensemble.RandomForestClassifier()
clf = clf.fit(X, Y)
features = X.columns
importances = clf.feature_importances_
idxrf = np.argsort(importances)[::-1]

plt.figure(figsize=(15,10))
sns.barplot(x=np.arange(len(idxrf)),y=importances[idxrf], color = 'black')
plt.xticks(range(len(idxrf)), [features[i] for i in idxrf], rotation='vertical')

plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Importance of Feature')

#number of features based on trees

features=79
rmse = np.zeros(features-1)

# loop over the Ks

train_error_vs_N = []
cv_error_vs_N = []

for i in range(1,features):
    trainingx=X.iloc[:,idxrf[0:i]]
    trainingy=Y

    linear_model=lm.LinearRegression()
    
    cv_results = cross_validate(linear_model, trainingx, trainingy, 
                                cv=5,scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(np.arange(1,features), train_error_vs_N)
sns.lineplot(np.arange(1,features), cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");
plt.title('Importance of Feature (Random Forest)')

print(cv_error_vs_N[5:15])

numfeaturesrf=20
# Out:
# [54296.62308498082, 45504.39412840914, 45473.47824490912, 36978.77689493065, 34836.8507030265, 33476.234052815205, 33475.50118868808, 33023.29526152175, 32445.257172834048, 32163.307324445206]

# %%
#Feature Importance (Gradient Boosting)

clf = ensemble.GradientBoostingClassifier(n_estimators=25,verbose=3)
clf = clf.fit(X, Y)
features = X.columns
importances = clf.feature_importances_
idxgb = np.argsort(importances)[::-1]

plt.figure(figsize=(15,10))
sns.barplot(x=np.arange(len(idxgb)),y=importances[idxgb], color = 'black')
plt.xticks(range(len(idxgb)), [features[i] for i in idxgb], rotation='vertical')

plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Importance of Feature')

#number of features based on gb

features=79
rmse = np.zeros(features-1)

# loop over the Ks

train_error_vs_N = []
cv_error_vs_N = []

for i in range(1,features):
    trainingx=X.iloc[:,idxgb[0:i]]
    trainingy=Y

    linear_model=lm.LinearRegression()
    
    cv_results = cross_validate(linear_model, trainingx, trainingy, 
                                cv=5,scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(np.arange(1,features), train_error_vs_N)
sns.lineplot(np.arange(1,features), cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");
plt.title('Importance of Feature (Gradient Boosting)')

print(cv_error_vs_N[10:20])

numfeaturesgb=20
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.5350           12.79m
#          2           1.0524           13.14m
#          3           0.9943           12.98m
#          4           0.9906           12.42m
#          5           0.9879           11.80m
#          6           0.9857           11.18m
#          7           0.9841           10.58m
#          8           0.9827            9.98m
#          9           0.9816            9.38m
#         10           0.9807            8.79m
#         11           0.9800            8.20m
#         12           0.9794            7.67m
#         13           0.9790            7.10m
#         14           0.9786            6.51m
#         15           0.9783            5.91m
#         16           0.9780            5.32m
#         17           0.9778            4.72m
#         18           0.9776            4.13m
#         19           0.9775            3.54m
#         20           0.9774            2.95m
#         21           0.9773            2.36m
#         22           0.9772            1.77m
#         23           0.9771            1.18m
#         24           0.9771           35.32s
#         25           0.9770            0.00s
# [36781.815578595495, 35788.45870536767, 33490.82773863162, 32797.56445414396, 32735.815175528063, 32624.47608300519, 32039.11487362718, 31573.113757606265, 31607.919086084537, 31394.429096792428]

# %%
#number of features based on corr

train_error_vs_N = []
cv_error_vs_N = []
linear_model=lm.LinearRegression()

num_cols = training_data.dtypes[(training_data.dtypes == 'int64') | (training_data.dtypes == 'float64')].index
corr_df = training_data.loc[:,num_cols].corr()
sale_price_corr = corr_df['SalePrice'].drop('SalePrice',axis=0).sort_values(ascending=False)

range_of_num_features = range(1, sale_price_corr.shape[0] + 1)

for N in range_of_num_features:
    sale_price_corr_first_N_features = sale_price_corr.iloc[:N]
    saleprice=training_data['SalePrice'].drop(training_data.index
                                              [training_data[sale_price_corr.iloc[:N].index]
                                               .isnull().any(1)])
    indepVar=training_data[sale_price_corr_first_N_features.index].dropna()
    
    scaler=preprocessing.StandardScaler()
    indepVar = pd.DataFrame(scaler.fit_transform(indepVar),columns = indepVar.columns)
    
    cv_results = cross_validate(linear_model, indepVar, saleprice, cv=4,
                                scoring=('r2', 'neg_root_mean_squared_error'),
                                return_train_score=True)
    
    train_error_overfit =-np.mean(cv_results['train_neg_root_mean_squared_error'])
    test_error_overfit=-np.mean(cv_results['test_neg_root_mean_squared_error'])
    train_error_vs_N.append(train_error_overfit)
    cv_error_vs_N.append(test_error_overfit)

plt.figure(figsize=(10,7))
sns.lineplot(range_of_num_features, train_error_vs_N)
sns.lineplot(range_of_num_features, cv_error_vs_N)
plt.legend(["Training Error", "CV Error"])
plt.xlabel("Number of Features")
plt.ylabel("RMSE");

# %% [markdown]
# Further illustration shows exactly where the dip occurs before the RMSE rises again. The valley seems to occur on the 14th variable.

# %%
print(cv_error_vs_N[10:20])

numfeaturescorr=16
# Out:
# [35365.4306383143, 35432.91093838564, 34465.27754495884, 34425.71223292293, 33992.93657602125, 32483.54605626102, 33073.66249508652, 33134.707228185966, 32868.04308013559, 32885.071227994034]

# %% [markdown]
# From the 14 variables, it is important to take out variables that are dependent on each other. A heat map with the correlation between the variables were made.
#
# For example, the amount of cars you can fit into a garage is highly correlated to the garage area, which makes sense. Therefore, we need to delete one of the variables.

# %%
#multicorr test

features=sale_price_corr.iloc[:numfeaturescorr]

plt.figure(figsize=(10,10))
sns.heatmap(training_data[features.index].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From observing the heat map, there were 5 variables that I decided to take out to minimize multicollinearity.

# %%
colinear=['TotRms_AbvGrd','Garage_Area','Year_Remod/Add','Full_Bath','Garage_Yr_Blt']

idxcorr=[]

for i in range(len(features.index.to_list())):
    idxcorr.append(training_data.columns.get_loc(sale_price_corr.index.to_list()[i]))
idxcorr.insert(0,76)
idxcorr=np.array(idxcorr)

# %% [markdown]
# ## Modeling

# %% [markdown]
# We will define our pipeline to create the dataframe that will be passed into the regression models.
#
# *Idea from Data 200*

# %%
def select_columns(data, columns):
    """Select only columns passed as arguments."""
    return data.iloc[:, columns]

def process_data_fm(data, overall_features):
    data = remove_outliers(data, 'Gr_Liv_Area', 4000)
    data = add_total_bathrooms(data)
    
    # Transform Data, Select Features
    data = add_in_rich_neighborhood(data, rich_neighborhoods)
    data = select_columns(data, overall_features)
        
    # Return predictors and response variables separately
    X = data.drop(['SalePrice'], axis = 1)
    
    numf=X.dtypes[(X.dtypes == 'int64') | (X.dtypes == 'float64')].index
    scaler=preprocessing.StandardScaler()
    X.loc[:,numf] = scaler.fit_transform(X.loc[:,numf])
    X = encode(X)
    
    y = data.loc[:, 'SalePrice']
    X=X.fillna(method="pad")
    X=X.fillna(method="bfill")
    return X, y

# %% [markdown]
# ### Ordinary Least Square

# %% [markdown]
# The first type of regression that will be conducted is the ordinary least square.
#
# The data was read in again and if there is no data in any of the 14 numerical columns we chose, the observation was removed. The data was then split into the test and training data.

# %%
def OLSrun(X_train_n, y_train, X_test_n, y_test):  

    final_model = lm.LinearRegression()
    final_model.fit(X_train_n, y_train)
    y_predicted_train = final_model.predict(X_train_n)
    y_predicted_test = final_model.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_predicted_train, y_train,squared=False)
    test_rmse = metrics.mean_squared_error(y_predicted_test, y_test,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    #Line Plot
    plt.figure(figsize=(10,7))
    ax=sns.scatterplot(y_predicted_train,y_train,label="Training")
    sns.scatterplot(y_predicted_test,y_test,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_predicted_train,y_train,label="Training")
    sns.residplot(y_predicted_test,y_test,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()

# %% [markdown]
# Only 19 rows were removed out of 2,000, which won't affect our analysis.

# %% [markdown]
# Both the training and test data will be processed into our pipeline that we defined earlier.

# %% [markdown]
# The training data was fitted into our linear regression model and from that the predicted training and test sales prices was determined.

# %% [markdown]
# The RMSE of the test and training dataset was calculated.

# %% [markdown]
# A residual plot of the RMSE and Predicted Sales Price shows that in general the regression was fine except for predicted sales price greater than 40,000, where there is a large absolute RMSE.

# %% [markdown]
# The predicted and actual sales price for the test dataset is plotted. There are a few outliers above the true sales price of 500,000.

# %% [markdown]
# ### Ridge Regression
#
# The second type of regression that will be implemented is the ridge regression. Since the regularization parameter depends on the coefficents of our regression, the data has to be standardized to prevent one feature from being overrepresented.

# %%
def ridgerun(X_train_n, y_train_n, X_test_n, y_test_n):
    
    param_grid = {'alpha': [0.01, 0.1, 1., 5., 10., 25., 50., 100.]}
    final_ridge = GridSearchCV(lm.Ridge(), cv=5, param_grid=param_grid, scoring='neg_mean_squared_error')
    final_ridge.fit(X_train_n, y_train_n)
    alpha = final_ridge.best_params_['alpha']
    print('Initial Best Alpha', alpha)
    
    param_gridimp = {'alpha': list(np.linspace(alpha-(alpha*0.2),alpha+(alpha*0.2),200))}
    final_ridgeimp = GridSearchCV(lm.Ridge(), cv=5, param_grid=param_gridimp, scoring='neg_mean_squared_error')
    final_ridgeimp.fit(X_train_n, y_train_n)
    alphaimp = final_ridgeimp.best_params_['alpha']
    print('Improved Best Alpha', round(alphaimp,2))
    
    
    y_ridge_train = final_ridgeimp.predict(X_train_n)
    y_ridge_test = final_ridgeimp.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_ridge_train, y_train_n,squared=False)
    test_rmse = metrics.mean_squared_error(y_ridge_test, y_test_n,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    
    #Line Plot
    plt.figure(figsize=(10,7))
    
    ax=sns.scatterplot(y_ridge_train,y_train_n,label="Training")
    sns.scatterplot(y_ridge_test,y_test_n,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_ridge_train,y_train_n,label="Training")
    sns.residplot(y_ridge_test,y_test_n,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()
    
    #Feature Importance
    ridge=final_ridgeimp.best_estimator_
    
    coefs = pd.DataFrame({'coefs':ridge.coef_}, index=X_train_n.columns)
    coefs['coefs_abs'] = np.abs(coefs.coefs)
    
    top_coefs = coefs.sort_values('coefs_abs', ascending=False).head(10)
    plt.figure(figsize=(8,10))
    sns.barplot( top_coefs.coefs_abs, top_coefs.index)
    plt.title('Ridge Regression: Top Features')
    plt.xlabel('Absolute Coefficient')
    plt.show()

# %% [markdown]
# First, the optimal hyperparameter needs to be found for the regression.

# %% [markdown]
# From determining best alpha, we can further refine the searching on what the best alpha should be.

# %% [markdown]
# The predicted sales price can then be determined from fitting the model.

# %% [markdown]
# A residual plot was then made. Here we can see that the same issue as the ordinary least squares regression where at around 2.1, there is a large absolute RMSE.

# %% [markdown]
# The same shows in our scatter plot of the predicted and actual sales price. There are four clear outliers where the sales price was underestimated.

# %% [markdown]
# ### Lasso Regression
#
# The third type of regression that will be implemented is the lasso regression. We will use the standardized data for the same reason as the ridge regression.

# %%
def lassorun(X_train_n, y_train_n, X_test_n, y_test_n):  

    param_grid = {'alpha': [0.01, 0.1, 1., 5., 10., 25., 50., 100., 500., 1000.]}
    final_lasso = GridSearchCV(lm.Lasso(), cv=5, param_grid=param_grid, scoring='neg_mean_squared_error')
    final_lasso.fit(X_train_n, y_train_n)
    alpha = final_lasso.best_params_['alpha']
    print('Initial Best Alpha', alpha)
    
    param_gridimp = {'alpha': list(np.linspace(alpha-(alpha*0.2),alpha+(alpha*0.2),1000))}
    final_lassoimp = GridSearchCV(lm.Lasso(), cv=5, param_grid=param_gridimp, scoring='neg_mean_squared_error')
    final_lassoimp.fit(X_train_n, y_train_n)
    alphaimp = final_lassoimp.best_params_['alpha']
    print('Improved Best Alpha', round(alphaimp,2))
    
    y_lasso_train = final_lassoimp.predict(X_train_n)
    y_lasso_test = final_lassoimp.predict(X_test_n)
    
    training_rmse = metrics.mean_squared_error(y_lasso_train, y_train_n,squared=False)
    test_rmse = metrics.mean_squared_error(y_lasso_test, y_test_n,squared=False)
    print('Training and Test Error:',round(training_rmse,2),round(test_rmse,2))
    
    
    #Line Plot
    plt.figure(figsize=(10,7))

    ax=sns.scatterplot(y_lasso_train,y_train_n,label="Training")
    sns.scatterplot(y_lasso_test,y_test_n,label="Test",ax=ax)
    sns.lineplot([0,600000],[0,600000],color='red')
    
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('Actual Sales Price')
    ax.legend(loc='upper left')
    plt.show()
    
    
    #Residual Plots
    plt.figure(figsize=(10,7))
    ax=sns.residplot(y_lasso_train,y_train_n,label="Training")
    sns.residplot(y_lasso_test,y_test_n,label="Test",ax=ax)
    plt.xlabel('Predicted Sales Price')
    plt.ylabel('RMSE')
    plt.title('Residual Plot')
    ax.legend(loc='upper left')
    plt.show()
    
    #Feature Importance
    lasso=final_lassoimp.best_estimator_
    
    coefs = pd.DataFrame({'coefs':lasso.coef_}, index=X_train_n.columns)
    coefs['coefs_abs'] = np.abs(coefs.coefs)
    
    top_coefs = coefs.sort_values('coefs_abs', ascending=False).head(10)
    plt.figure(figsize=(8,10))
    sns.barplot( top_coefs.coefs_abs, top_coefs.index)
    plt.title('LASSO Regression: Top Features')
    plt.xlabel('Absolute Coefficient')
    plt.show()

# %% [markdown]
# We see that the lack of a hyperparameter is optimal for the lasso regression, which means that there is not enough features where a regularization parameter would help reduce the error.

# %% [markdown]
# The predicted sales price is then determined.

# %% [markdown]
# A residual plot was then made and the same pattern is seen as the ridge regression.

# %% [markdown]
# The same pattern shows in our scatter plot as the ridge regression where there are four clear outliers where the sales price was underestimated.

# %%
def runmodels(training_data, test_data, numfeatures, idx):
    training_data = add_total_SF(training_data)
    test_data = add_total_SF(test_data)
    
    X_train, y_train=process_data_fm(training_data,idx[0:numfeatures])
    X_test, y_test=process_data_fm(test_data,idx[0:numfeatures])
    
    X_train_r2 = sm.add_constant(X_train)
    models = sm.OLS(y_train,X_train_r2)
    results = models.fit()
    print(results.summary())
    
    X_train_n = X_train
    X_test_n = X_test
    
    OLSrun(X_train_n, y_train, X_test_n, y_test)
    ridgerun(X_train_n, y_train, X_test_n, y_test)
    lassorun(X_train_n, y_train, X_test_n, y_test)

# %%
##### Running each model ########

full_data = pd.read_csv('https://raw.githubusercontent.com/benchang123/Ames-Housing/master/ames.csv')

#drop too many nan
nan=nanmean[nanmean>25].sort_values(ascending=False)
full_data.drop(columns=nan.index,inplace=True)

training_data, test_data = train_test_split(full_data, random_state=42, test_size=0.2)

training_data.shape
# Out:
# (1600, 77)

# %%
#RF
runmodels(training_data, test_data, numfeaturesrf, idxrf)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     494.6
# Date:                Sun, 25 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:33:22   Log-Likelihood:                -18795.
# No. Observations:                1598   AIC:                         3.763e+04
# Df Residuals:                    1578   BIC:                         3.774e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.815e+05    781.027    232.392      0.000     1.8e+05    1.83e+05
# PID             -793.3976    862.820     -0.920      0.358   -2485.792     898.997
# Order           1340.0998    809.075      1.656      0.098    -246.876    2927.075
# Overall_Qual    2.461e+04   1294.893     19.009      0.000    2.21e+04    2.72e+04
# Bedroom_AbvGr  -9911.0387   1046.139     -9.474      0.000    -1.2e+04   -7859.070
# Lot_Area        5996.5367    860.483      6.969      0.000    4308.726    7684.347
# 1st_Flr_SF      2418.2220   1431.101      1.690      0.091    -388.837    5225.281
# Bsmt_Unf_SF     -199.4078   2245.835     -0.089      0.929   -4604.542    4205.726
# Gr_Liv_Area     1.985e+04   3.24e+04      0.612      0.541   -4.38e+04    8.35e+04
# Total_SF        2.047e+04   5.08e+04      0.403      0.687   -7.91e+04     1.2e+05
# Garage_Area     7946.8772   1052.744      7.549      0.000    5881.954       1e+04
# Total_Bsmt_SF  -1397.6990   2.79e+04     -0.050      0.960   -5.61e+04    5.33e+04
# Lot_Frontage    3573.6360    886.360      4.032      0.000    1835.068    5312.204
# Garage_Yr_Blt   -481.8207   1375.065     -0.350      0.726   -3178.968    2215.326
# Year_Built      5963.8764   1463.013      4.076      0.000    3094.223    8833.529
# BsmtFin_SF_1    1.135e+04   2344.016      4.840      0.000    6747.852    1.59e+04
# Mo_Sold         -230.5939    797.512     -0.289      0.773   -1794.889    1333.701
# Year_Remod/Add  6813.5223   1123.301      6.066      0.000    4610.202    9016.842
# Open_Porch_SF    203.9631    854.571      0.239      0.811   -1472.251    1880.178
# Wood_Deck_SF     708.5822    833.498      0.850      0.395    -926.298    2343.462
# ==============================================================================
# Omnibus:                      437.004   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3101.836
# Skew:                           1.085   Prob(JB):                         0.00
# Kurtosis:                       9.471   Cond. No.                         205.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 31022.35 29872.12
# Initial Best Alpha 50.0
# Improved Best Alpha 60.0
# Training and Test Error: 31069.98 29598.0
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 604959782810.4523, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642971862336.2996, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 599508407593.4486, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 604434207962.1196, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4615731653.273682, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 551744375762.052, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 573448042713.3005, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 538616562102.2095, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 534684910255.27136, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4617297583.432739, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228281136664.82904, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 208875031706.28955, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193731326710.69342, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 179004200632.45007, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4632908874.893677, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44897910438.38086, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38071964283.21179, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34745077568.43823, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31223463126.708862, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4701254637.771973, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20242842601.342407, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17509169918.69922, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15759489482.739868, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14477363316.798584, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4784303744.220947, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7953387183.189453, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6998631215.11499, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6770328765.351807, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5017563749.010132, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 1000.0
# Improved Best Alpha 933.33
# Training and Test Error: 31138.22 29585.57

# %%
#GB
runmodels(training_data, test_data, numfeaturesgb, idxgb)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     502.1
# Date:                Sun, 25 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:33:55   Log-Likelihood:                -18784.
# No. Observations:                1598   AIC:                         3.761e+04
# Df Residuals:                    1578   BIC:                         3.772e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.79e+05   1866.246     95.906      0.000    1.75e+05    1.83e+05
# Wood_Deck_SF   1364.0900    826.072      1.651      0.099    -256.225    2984.405
# PID             794.5953    890.630      0.892      0.372    -952.347    2541.537
# Order           990.0928    793.920      1.247      0.213    -567.156    2547.342
# Bedroom_AbvGr -1.012e+04   1036.690     -9.766      0.000   -1.22e+04   -8090.458
# 1st_Flr_SF     7352.6802   7264.106      1.012      0.312   -6895.634    2.16e+04
# Overall_Qual   2.498e+04   1270.726     19.657      0.000    2.25e+04    2.75e+04
# Gr_Liv_Area     2.55e+04   9125.281      2.794      0.005    7599.530    4.34e+04
# Lot_Area       6134.5217    855.056      7.174      0.000    4457.356    7811.687
# Bsmt_Unf_SF      99.4274   2233.829      0.045      0.965   -4282.157    4481.012
# Neighborhood    185.6082    124.244      1.494      0.135     -58.092     429.309
# Garage_Yr_Blt  1938.5191   1340.071      1.447      0.148    -689.987    4567.026
# BsmtFin_SF_1   1.047e+04   2338.433      4.477      0.000    5881.686    1.51e+04
# Lot_Frontage   3340.6929    882.390      3.786      0.000    1609.912    5071.474
# 2nd_Flr_SF     6031.5352   7856.181      0.768      0.443   -9378.115    2.14e+04
# Total_Bsmt_SF  9179.2169   2481.155      3.700      0.000    4312.511     1.4e+04
# Mas_Vnr_Area   6683.1249    907.849      7.361      0.000    4902.407    8463.843
# Garage_Area    6802.9539   1052.583      6.463      0.000    4738.345    8867.563
# Open_Porch_SF   877.5366    850.598      1.032      0.302    -790.884    2545.957
# Year_Built     7358.4557   1445.688      5.090      0.000    4522.784    1.02e+04
# ==============================================================================
# Omnibus:                      369.342   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2397.377
# Skew:                           0.915   Prob(JB):                         0.00
# Kurtosis:                       8.715   Cond. No.                         275.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 30823.53 29356.11
# Initial Best Alpha 100.0
# Improved Best Alpha 82.01
# Training and Test Error: 30884.18 29109.2
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 460895301490.00305, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 534137537167.8487, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 512115881057.61926, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547187194584.0718, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 507459027590.19836, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94455428552.69482, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124579923344.87585, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 154323566398.8214, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 212023262434.77008, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170588513205.28052, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2322450564.39624, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3458329776.2158203, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5287567596.886108, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9797078887.223999, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6712130243.3359375, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 1000.0
# Improved Best Alpha 982.18
# Training and Test Error: 30959.11 29093.81

# %%
#corr
runmodels(training_data, test_data, numfeaturescorr, idxcorr)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     569.1
# Date:                Sun, 25 Apr 2021   Prob (F-statistic):               0.00
# Time:                        12:34:29   Log-Likelihood:                -18862.
# No. Observations:                1598   AIC:                         3.776e+04
# Df Residuals:                    1582   BIC:                         3.784e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.815e+05    813.430    223.167      0.000     1.8e+05    1.83e+05
# TotalBathrooms  9843.2472   1338.495      7.354      0.000    7217.837    1.25e+04
# Overall_Qual     2.34e+04   1357.354     17.240      0.000    2.07e+04    2.61e+04
# Gr_Liv_Area     3401.6286   3.38e+04      0.101      0.920   -6.28e+04    6.96e+04
# Total_Bsmt_SF  -6960.5991   2.89e+04     -0.241      0.810   -6.37e+04    4.98e+04
# 1st_Flr_SF      8332.2174   1454.137      5.730      0.000    5479.980    1.12e+04
# Garage_Cars     -137.9415   1963.039     -0.070      0.944   -3988.373    3712.490
# Garage_Area     9782.8979   1883.834      5.193      0.000    6087.825    1.35e+04
# Year_Built      4484.1621   1571.665      2.853      0.004    1401.396    7566.928
# Year_Remod/Add  8818.0263   1168.570      7.546      0.000    6525.917    1.11e+04
# Full_Bath       -1.03e+04   1357.751     -7.587      0.000    -1.3e+04   -7637.938
# Garage_Yr_Blt    744.4129   1443.841      0.516      0.606   -2087.630    3576.456
# Total_SF        3.253e+04   5.28e+04      0.616      0.538    -7.1e+04    1.36e+05
# Mas_Vnr_Area    7652.4608    941.053      8.132      0.000    5806.619    9498.303
# TotRms_AbvGrd  -1261.2798   1452.872     -0.868      0.385   -4111.036    1588.476
# Fireplaces      5266.1196    980.011      5.374      0.000    3343.862    7188.377
# ==============================================================================
# Omnibus:                      412.075   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2327.635
# Skew:                           1.083   Prob(JB):                         0.00
# Kurtosis:                       8.502   Cond. No.                         230.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Training and Test Error: 32351.07 31022.36
# Initial Best Alpha 10.0
# Improved Best Alpha 12.0
# Training and Test Error: 32354.98 30963.95
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 671110280355.6069, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 695042139765.3823, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 655929254035.4308, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 666272081238.2382, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232917996306.05566, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 658902567313.1954, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 682869151606.8688, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 643604304374.6484, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 653579125898.8452, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232934898164.7024, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 548247999175.3745, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 572265992288.2385, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 508862706275.3799, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 510261696375.26746, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233097485758.63702, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205019354271.23474, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217922845204.21594, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205345473528.33337, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 205309413675.88184, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233678641599.85962, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99709294459.86572, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107152578848.93713, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100823326491.5039, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101053686757.9613, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8580351843.5979, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34869896058.12378, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37460227612.77954, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35345149345.565796, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35818038661.20508, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8967132257.894531, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18076512698.895508, tolerance: 831268931.4165038
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19173195554.73169, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18155969579.352783, tolerance: 821774594.2901276
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18648130957.576904, tolerance: 870246775.1965741
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9553966209.554688, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10509787899.723877, tolerance: 859516305.1975329
#   positive)
# Initial Best Alpha 100.0
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3324013949.5771484, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10162340078.124756, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3105875855.53125, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10163119987.43335, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2902319520.0654297, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10163899748.490723, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2704532928.4467773, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10164679361.293457, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2512582469.7768555, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10165458825.833008, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2340495036.6723633, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10166238142.105957, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2175524883.756592, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10167017310.131104, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2015630156.4536133, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10167796329.884521, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1864430869.4138184, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10168575201.393799, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1729119766.2597656, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10169353924.6333, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1598113628.006836, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10170132499.615723, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1471451015.2575684, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10170910926.336182, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1356925501.3549805, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10171689204.798584, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1251340561.664795, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10172467335.013916, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1149344525.6577148, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10173139582.546875, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 994253189.7023926, tolerance: 895104701.8888875
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10173746256.481201, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10174352612.140625, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10174958649.546387, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10175564368.685059, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10176169769.556396, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10176880358.584717, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10177656281.914307, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10178432056.48291, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10179207682.279541, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10179983159.312744, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10180758487.584229, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10181533667.093994, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10182308697.830322, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10183083579.799805, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10183858313.016602, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10184632897.469482, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10185407333.138672, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10186181620.064209, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10186955758.216553, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10187729747.59668, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10188503588.223633, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10189277280.077148, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10190050823.17041, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10190824217.501709, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10191597463.057129, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10192370559.864502, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10193143507.890625, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10193760582.481934, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10194362026.810303, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10194963154.67871, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10195563966.092285, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10196164461.04663, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10196764639.544678, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10197491467.738525, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10198262190.691406, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10199032764.368408, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10199803188.782227, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10200573463.917236, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10201343589.787598, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10202113566.38208, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10202883393.702637, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10203653071.768555, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10204422600.546875, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10205191980.061768, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10205961210.312256, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10206730291.28711, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10207499222.989014, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10208268005.418701, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10209036638.5896, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10209805122.47998, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10210573457.09961, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10211341642.456299, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10212109678.531982, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10212877565.335693, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10213645302.874023, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10214339605.848389, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10214935921.620361, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10215531922.729248, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10216127609.197021, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10216722981.006348, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10217318038.16919, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10217927604.096924, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10218693098.340332, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10219458442.81958, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10220223637.513672, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10220988682.436523, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10221753577.585938, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10222518322.94873, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10223282918.545654, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10224047364.364014, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10224811660.4021, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10225575806.669434, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10226339803.151123, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10227103649.863525, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10227867346.80249, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10228630893.960205, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10229394291.341797, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10230157538.941162, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10230920636.77832, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10231683584.827637, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10232446383.11206, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10233209031.60669, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10233971530.329834, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10234733879.273193, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10235472184.657715, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10236063160.070312, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10236653822.62915, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10237244172.33496, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10237834209.193604, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10238423933.210205, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10239013344.380127, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10239707902.179932, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10240467838.84082, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10241227625.221924, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10241987261.32129, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10242746747.14624, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10243506082.682617, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10244265267.9375, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10245024302.902344, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10245783187.602783, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10246541922.007324, tolerance: 859516305.1975329
#   positive)
# ...
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10514935884.023438, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10515621619.583984, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10516307199.299316, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10516992623.173828, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10517677891.205078, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10518363003.39331, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10519047959.733643, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10519732760.224121, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10520417404.882568, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10521101893.678467, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10521786226.64038, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10522470403.757324, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10523154425.027588, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10523838290.45581, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10524522000.030518, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10525205553.763428, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10525888951.647217, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10526572193.69165, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10527255279.893799, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10527938210.245361, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10528620984.75708, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10529303603.412842, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10529867501.510498, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10530378677.198975, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10495371554.763184, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10427639527.615723, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9814293627.80664, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9133938591.96582, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8385128719.748779, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7634763584.960449, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6909597974.37085, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6290413522.024902, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5952869207.540283, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5629583856.026123, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5313242598.60791, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5007366366.5095215, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4718549543.30957, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4436419197.283936, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4163524023.583496, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3909621752.9384766, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3662017480.5898438, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3421882817.9780273, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3202104275.2177734, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2988129663.7561035, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2780035856.697998, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2592217031.7026367, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2410090508.4624023, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2233258311.680664, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2073916070.0922852, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1921194153.814209, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1773131893.9360352, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1639519652.3710938, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1513306756.5004883, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1391102475.9953613, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1280299191.199463, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1177453169.3535156, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1077977885.9560547, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 987038968.6293945, tolerance: 859516305.1975329
#   positive)
# C:\Users\bench\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 904359388.6601562, tolerance: 859516305.1975329
#   positive)
# Improved Best Alpha 119.84
# Training and Test Error: 32356.02 30965.08

# %% [markdown]
# # Conclusion
#
# In the end, we determined that using 9 numberical variables was optimal for our regression. A few categorical variables were added that would intuitively correlate to the sales price and improve our model.
#
# Areas of improvement for our model including trying to find a method that determines the best categorical variables to use, as only three were used in this notebook. Adding more categorical variables that are highly correlated to the sales price would help fit our data better to our chosen model and reduce test errors. It would also be helpful to further address a few outliers which was throwing off our regression. Perhaps using a different type of model would help accrurately predict the sales price of houses.
